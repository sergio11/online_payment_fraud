# %%
from sklearn.model_selection import train_test_split

# Define the train_val_test_split function
def train_val_test_split(df, rstate=42, shuffle=True, stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.4, random_state=rstate, shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate, shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
# Define the remove_labels function
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
import pandas as pd
import os

# Directory where the CSV file is located
directory = 'data'
filename = 'onlinefraud.csv'

# Read the CSV file and create a DataFrame with Pandas
df = pd.read_csv(os.path.join(directory, filename), delimiter=',')

# Print the filename and the number of records in the DataFrame
print(f"Processed file: {filename}")
print(f"Number of records: {len(df)}\n")
# Out:
# Processed file: onlinefraud.csv
# Number of records: 368937

# %%
print("Number of features:", len(df.columns))
print("Length of the dataset:", len(df))
# Out:
# Number of features: 11
# Length of the dataset: 368937

# %%
df.head(200)
# Out:
#      step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1       1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2       1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3       1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4       1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ..    ...       ...        ...          ...            ...             ...
# 195     1  CASH_OUT  210370.09  C2121995675            0.0            0.00
# 196     1  CASH_OUT   36437.06  C2120063568            0.0            0.00
# 197     1  CASH_OUT   82691.56  C1620409359            0.0            0.00
# 198     1  CASH_OUT  338767.10   C691691381            0.0            0.00
# 199     1  CASH_OUT  187728.59   C264978436            0.0            0.00
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0    M1979787155            0.00            0.00      0.0             0.0
# 1    M2044282225            0.00            0.00      0.0             0.0
# 2     C553264065            0.00            0.00      1.0             0.0
# 3      C38997010        21182.00            0.00      1.0             0.0
# 4    M1230701703            0.00            0.00      0.0             0.0
# ..           ...             ...             ...      ...             ...
# 195  C1170794006      1442298.03        22190.99      0.0             0.0
# 196  C1740000325       154606.00      1363368.51      0.0             0.0
# 197   C248609774       657983.89      6453430.91      0.0             0.0
# 198   C453211571       544481.28      3461666.05      0.0             0.0
# 199  C1360767589       394124.51      2107965.39      0.0             0.0
#
# [200 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368937 entries, 0 to 368936
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            368937 non-null  int64
#  1   type            368937 non-null  object
#  2   amount          368936 non-null  float64
#  3   nameOrig        368936 non-null  object
#  4   oldbalanceOrg   368936 non-null  float64
#  5   newbalanceOrig  368936 non-null  float64
#  6   nameDest        368936 non-null  object
#  7   oldbalanceDest  368936 non-null  float64
#  8   newbalanceDest  368936 non-null  float64
#  9   isFraud         368936 non-null  float64
#  10  isFlaggedFraud  368936 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  368937.000000  3.689360e+05   3.689360e+05    3.689360e+05
# mean       12.333973  1.739160e+05   9.025764e+05    9.219139e+05
# std         3.032426  2.900787e+05   2.956128e+06    2.993238e+06
# min         1.000000  1.000000e-01   0.000000e+00    0.000000e+00
# 25%        10.000000  1.326657e+04   0.000000e+00    0.000000e+00
# 50%        13.000000  8.081283e+04   1.802300e+04    0.000000e+00
# 75%        15.000000  2.313149e+05   1.756088e+05    2.162749e+05
# max        17.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud  isFlaggedFraud
# count    3.689360e+05    3.689360e+05  368936.000000        368936.0
# mean     9.828249e+05    1.186699e+06       0.000539             0.0
# std      2.359402e+06    2.562465e+06       0.023219             0.0
# min      0.000000e+00    0.000000e+00       0.000000             0.0
# 25%      0.000000e+00    0.000000e+00       0.000000             0.0
# 50%      1.010667e+05    2.096439e+05       0.000000             0.0
# 75%      8.772334e+05    1.228213e+06       0.000000             0.0
# max      4.138365e+07    4.148270e+07       1.000000             0.0
